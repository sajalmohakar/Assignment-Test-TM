# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
data=pd.read_csv("Desktop/py/Data Science/b101test/test_zomato.csv")

# %%
data.head()
# Out:
#   Unnamed: 0 Restaurant ID         Restaurant Name  Country Code  \
# 0          0       6317637        Le Petit Souffle         162.0
# 1          1       6304287        Izakaya Kikufuji         162.0
# 2          2       6300002  Heat - Edsa Shangri-La         162.0
# 3          3       6318506                    Ooma         162.0
# 4          4       6314302             Sambo Kojin         162.0
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0               0
# Restaurant ID            0
# Restaurant Name          0
# Country Code             0
# City                     0
# Address                  0
# Locality                 1
# Locality Verbose         1
# Longitude                1
# Latitude                 1
# Cuisines                10
# Average Cost for two     1
# Currency                 1
# Has Table booking        1
# Has Online delivery      1
# Is delivering now        1
# Switch to order menu     1
# Price range              2
# Aggregate rating         2
# Rating color             2
# Rating text              2
# Votes                    2
# dtype: int64

# %%
data.dropna()
# Out:
#      Unnamed: 0 Restaurant ID           Restaurant Name  Country Code  \
# 0             0       6317637          Le Petit Souffle         162.0
# 1             1       6304287          Izakaya Kikufuji         162.0
# 2             2       6300002    Heat - Edsa Shangri-La         162.0
# 3             3       6318506                      Ooma         162.0
# 4             4       6314302               Sambo Kojin         162.0
# ...         ...           ...                       ...           ...
# 9547       9546       5915730              NamlÛ± Gurme         208.0
# 9548       9547       5908749             Ceviz AÛôacÛ±         208.0
# 9549       9548       5915807                     Huqqa         208.0
# 9550       9549       5916112              Aôôk Kahve         208.0
# 9551       9550       5927402  Walter's Coffee Roastery         208.0
#
#                   City                                            Address  \
# ...

# %%
data.fillna(0)
# Out:
#      Unnamed: 0 Restaurant ID           Restaurant Name  Country Code  \
# 0             0       6317637          Le Petit Souffle         162.0
# 1             1       6304287          Izakaya Kikufuji         162.0
# 2             2       6300002    Heat - Edsa Shangri-La         162.0
# 3             3       6318506                      Ooma         162.0
# 4             4       6314302               Sambo Kojin         162.0
# ...         ...           ...                       ...           ...
# 9547       9546       5915730              NamlÛ± Gurme         208.0
# 9548       9547       5908749             Ceviz AÛôacÛ±         208.0
# 9549       9548       5915807                     Huqqa         208.0
# 9550       9549       5916112              Aôôk Kahve         208.0
# 9551       9550       5927402  Walter's Coffee Roastery         208.0
#
#                   City                                            Address  \
# ...

# %%
df=data[['City','Average Cost for two']]
df.iloc[0:10].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[141], line 2
#       1 df=data[['City','Average Cost for two']]
# ----> 2 df.iloc[0:10].plot(kind='bar')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
# ...

# %%
df=data[['Restaurant Name','Aggregate rating']]
df.iloc[1400:1405].plot(kind='bar')
# Out:
# <Axes: >

# %%
# The indian restaurant having below 4/5 rating are Zoe.

# %%
df=data[['Restaurant ID','Price range']]
df.iloc[1400:1405].plot(kind='bar')
# Out:
# <Axes: >

# %%
# Conclusion

# %%
# The indian restaurant having below 4/5 rating are Zoe.

# %%
# The restaurant which is most expensive is Punjabi Tadka, First eat and Zoe and AS per Average cost per person data, The zoe is more expensive

# %%
# The restaurant which is more cheapest are as price range data is first eat

# %%
# I am unable to add average cost column which will make me easy analysis.
